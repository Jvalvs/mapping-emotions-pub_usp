# %%
# %pip install -U sentence-transformers

# %% [markdown]
# # Extraindo Labels

# %%
from transformers import RobertaTokenizerFast, TFRobertaForSequenceClassification, pipeline

tokenizer = RobertaTokenizerFast.from_pretrained("bhadresh-savani/bert-base-go-emotion")
model = TFRobertaForSequenceClassification.from_pretrained("bhadresh-savani/bert-base-go-emotion",from_pt=True)

emotion = pipeline('sentiment-analysis',
                    model="bhadresh-savani/bert-base-go-emotion",
                    return_all_scores=True)

# %%
import gdown
import pandas as pd

#Recebendo planilha com as coordenadas das emoções.
url1 = 'https://drive.google.com/uc?id=1yJBHU8Zl4MuoQfJqkPgVDwJfYRJDPUAH'
output = 'emotions_coord.xlsx'
gdown.download(url1, output, quiet=False)
emotions_coord = pd.read_excel(output)

# %%
emotions_coord
# Out:
#            Emotion     X     Y
# 0       admiration  0.38 -0.08
# 1        amusement  0.56  0.19
# 2            anger -0.41  0.78
# 3        annoyance -0.45  0.66
# 4         approval  0.95 -0.17
# 5           caring  0.76 -0.60
# 6        confusion -0.57 -0.69
# 7        curiosity  0.65  0.10
# 8           desire  0.42  0.65
# 9   disappointment -0.80 -0.02
# 10     disapproval -0.68  0.32
# 11         disgust -0.68  0.49
# 12   embarrassment -0.32 -0.60
# 13      excitement  0.70  0.72
# 14            fear -0.11  0.78
# 15       gratitude  0.90 -0.30
# 16           grief -0.90 -0.30
# 17             joy  0.95  0.13
# 18            love  0.85 -0.14
# 19     nervousness -0.68 -0.17
# 20        optimism  0.32  0.06
# 21           pride  0.62  0.50
# 22     realization  0.88  0.36
# 23          relief  0.71 -0.67
# 24         remorse -0.41 -0.43
# 25         sadness -0.82 -0.40
# 26        surprise  0.42  0.88
# 27         neutral  0.00  0.00

# %%
#Função que dada uma emoção e seus scores, toma o maior e determina sua coordenada no mapa.

def generate_coord(labels):
  df = pd.DataFrame(labels)
  highest_score = max(df['score'])
  indice = df.loc[df['score'] == highest_score].index[0]
  result = df.iloc[indice]['label']
  index = emotions_coord.loc[emotions_coord['Emotion'] == result].index[0]
  x = emotions_coord.iloc[index]['X']
  y = emotions_coord.iloc[index]['Y']
  return (x,y)

# %% [markdown]
# **Gerando textos para testes**

# %%
coord = []
emotion_labels = emotion("love u")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("i hate go to school")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels
# Out:
# [[{'label': 'admiration', 'score': 0.0031309870537370443},
#   {'label': 'amusement', 'score': 0.002098129829391837},
#   {'label': 'anger', 'score': 0.6745840311050415},
#   {'label': 'annoyance', 'score': 0.10060076415538788},
#   {'label': 'approval', 'score': 0.00833638571202755},
#   {'label': 'caring', 'score': 0.005283866077661514},
#   {'label': 'confusion', 'score': 0.0020115342922508717},
#   {'label': 'curiosity', 'score': 0.0018346766009926796},
#   {'label': 'desire', 'score': 0.001317880698479712},
#   {'label': 'disappointment', 'score': 0.018958421424031258},
#   {'label': 'disapproval', 'score': 0.03139863908290863},
#   {'label': 'disgust', 'score': 0.05738198012113571},
#   {'label': 'embarrassment', 'score': 0.005000021308660507},
#   {'label': 'excitement', 'score': 0.0023884051479399204},
#   {'label': 'fear', 'score': 0.0019162900280207396},
#   {'label': 'gratitude', 'score': 0.003922626841813326},
#   {'label': 'grief', 'score': 0.0019261104753240943},
# ...

# %%
x, y = generate_coord(emotion_labels[0])

# %%
emotion_labels = emotion("I was expecting more")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("I don't approve of what they're doing")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("That's disgusting")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("I was so embarrassed when I realized my mistake")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("I can't wait to try that")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("i really appreciate what you did for me")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("I wish they were still here with me")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("I'm so nervous about the interview tomorrow")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("I'm hopeful for the future")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("I'm so proud of what I accomplished")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("I was so surprised by the gift they gave me")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("brazil is a beautiful country")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("im really confused")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("I wonder whats going on in there")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("I wish I could have that")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("miss you so much")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("tomorrow is a new day")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("The thought of losing someone close to me fills me with anxiety and fear.")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("Hearing about the suffering and hardships of others can be really heartbreaking..")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("Being surrounded by nature always makes me feel more peaceful and calm.")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("Listening to my favorite music always lifts my mood and brings me joy.")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("Seeing someone I care about upset and unhappy makes me feel sad.")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("Watching a beautiful sunrise always fills me with wonder and awe.")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("I feel so proud of myself when I achieve something that I've been working towards.")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("I feel so happy when I'm with my friends.")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("It's so frustrating when things don't go according to plan.")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("When I see acts of kindness and compassion, it restores my faith in humanity.")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("Seeing children playing and laughing together always warms my heart.")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("I'm so anxious about the upcoming exam.")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("I feel so disappointed when I let myself down.")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion(" I like the feeling of accomplishment after a hard workout.")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
emotion_labels = emotion("I get really angry when people are rude and disrespectful.")
x, y = generate_coord(emotion_labels[0])
coord.append((x,y))

# %%
#HEATMAP
import matplotlib.pyplot as plt
import numpy as np
import math

df = pd.DataFrame(coord)
array_x = df[0].to_numpy()
x = array_x.tolist()
array_y = df[1].to_numpy()
y = array_y.tolist()

#Definindo tamanho do grid e do raio(h)
grid_size=0.05
h=0.5

#Tomando valores de máximos e mínimos de X e Y.
x_min=-1
x_max=1
y_min=-1
y_max=1

#Construindo grid
x_grid=np.arange(x_min-h,x_max+h,grid_size)
y_grid=np.arange(y_min-h,y_max+h,grid_size)
x_mesh,y_mesh=np.meshgrid(x_grid,y_grid)

#Determinando ponto central do grid
xc=x_mesh+(grid_size/2)
yc=y_mesh+(grid_size/2)

# %%
print(x_min,x_max,y_min,y_max)
# Out:
# -1 1 -1 1

# %%
#Função para calcular intensidade com Quartic Kernel
def kde_quartic(d,h):
    dn=d/h
    P=(15/16)*(1-dn**2)**2
    return P

# %%
intensity_list=[]
for j in range(len(xc)):
    intensity_row=[]
    for k in range(len(xc[0])):
        kde_value_list=[]
        for i in range(len(x)):
            #Calculando distância
            d=math.sqrt((xc[j][k]-x[i])**2+(yc[j][k]-y[i])**2)
            if d<=h:
                p=kde_quartic(d,h)
            else:
                p=0
            kde_value_list.append(p)
        #Soma os valores de intensidade
        p_total=sum(kde_value_list)
        intensity_row.append(p_total)
    intensity_list.append(intensity_row)

#Saída do Heatmap
intensity=np.array(intensity_list)
plt.pcolormesh(x_mesh,y_mesh,intensity)
plt.plot(x,y,'ro')
plt.show()

# %%
# %pip install pillow
from PIL import Image


import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


intensity_list=[]
for j in range(len(xc)):
    intensity_row=[]
    for k in range(len(xc[0])):
        kde_value_list=[]
        for i in range(len(x)):
            #Calculando distância
            d=math.sqrt((xc[j][k]-x[i])**2+(yc[j][k]-y[i])**2)
            if d<=h:
                p=kde_quartic(d,h)
            else:
                p=0
            kde_value_list.append(p)
        #Soma os valores de intensidade
        p_total=sum(kde_value_list)
        intensity_row.append(p_total)
    intensity_list.append(intensity_row)

#Saída do Heatmap
intensity=np.array(intensity_list)
plt.pcolormesh(x_mesh,y_mesh,intensity)
plt.plot(x,y,'ro')
plt.colorbar()
plt.show()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %pip install scikit-image

# %%
from PIL import Image
from skimage.transform import resize

# Carregar a imagem e o mapa de calor
imagem = Image.open('/content/emotion_wheel.png')

# Redimensionar o mapa de calor para as mesmas dimensões da imagem
heatmap_redimensionado = resize(intensity, (imagem.height, imagem.width))

# Converter a imagem e o mapa de calor para arrays numpy
imagem_array = np.array(imagem)
heatmap_array = np.array(heatmap_redimensionado)

# Plotar a imagem
plt.imshow(imagem_array)

# Plotar o mapa de calor com transparência controlada
plt.imshow(heatmap_array, cmap='hot', alpha=0.65)

# Configurar a barra de cores
plt.colorbar()

# Exibir o gráfico
plt.show()
